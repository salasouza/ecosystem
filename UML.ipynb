# %%
from IPython.display import display
from PIL import Image

# %% [markdown]
# <h4>Arquitetura do Docker</h4>

# %%
path="../images/docker_uml.png"

display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1236x581 at 0x7F74C84DE6D0>

# %% [markdown]
# <h4>Arquitetura do Pipeline</h4>

# %%
path="../images/pipeline_uml.png"

display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1091x791 at 0x7F74C84DE3A0>
